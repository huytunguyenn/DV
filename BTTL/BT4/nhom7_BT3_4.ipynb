# %% [markdown]
# Nhóm 7:
# - 18120544	Trương Minh Tài
# - 18120231	Trần Xuân Quý
# - 18120009	Vương Gia Bảo
# - 18120249	Hồ Minh Trí

# %% [markdown]
# # Bài tập 3

# %% [markdown]
# STEP 1:  Close your eyes and then look at the graph. Where do your eyes focus first?
# Why is that? In looking more closely at the data, is that where we want our audience to look?

# %% [markdown]
# Điểm tập trung đầu tiên là:
# - The store has a nice atmosphere
# - The store offers items I can't find elsewhere
#
# Nhìn kỹ vào biểu đồ, mắt tập trung vào phần lớn nhất ở bên phải ( phần được khoanh đỏ), có chỉ số cao đó được nổi bật lên so với đồ thị

# %% [markdown]
# STEP 2: What takeaway(s) would you highlight in this data? Identify a few observations you could make. What is the primary message you'd communicate? Put it into words.

# %% [markdown]
# Dựa vào đồ thị, dễ thấy được tiêu chí về việc tạo được bầu không khí dễ chịu, cung cấp được các mẫu sản phẩm mới và có những vật phẩm độc đáo của cửa hàng cao hơn rất nhiều so với mặt bằng chung, đây có thể là một điểm mạnh mà cửa hàng có thể khai thác.
# Tuy nhiên, các khía cạnh khác như về quảng cáo, giá bán, sản phẩm phù hợp nhu cầu người mua, sự giúp đỡ của nhân viên cũng như kích thước sản phẩm phù hợp chưa dược đánh giá cao. Đây là nhưng hạng mục mà cửa hàng nên tập trung cải thiện để thu hút khách hơn.
# Các tiêu chí còn lại khá phù hợp với yêu cầu của khách hàng, cửa hàng có thể giữ vững cách thực hiện để hướng tới cải thiện các tiêu chí chưa ổn.

# %% [markdown]
# STEP 3: Are there other ways to show this data that could make the primary message you outlined in Step 2 more quickly clear? How would you visualize this data to lend insight into what we should focus on in this scenario? Draw or download the data and create your preferred visual(s) using the tool of your choice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Bài tập 4

# %% [markdown]
# STEP 1: Study the provided data set. Write one or two sentences outlining the key takeaways.

# %% [markdown]
# Q3 là quý đồng thời có số lượng nhân viên xin nghỉ việc, được tuyển mới, tuyển lại và điều chuyển từ bộ phận khác vào nhiều nhất. Ngoài ra số nhân viên tiếp tục làm việc từ quý trước chỉ có 5 người, cũng là ít nhất. Có thể nói nhân lực cần khoảng 20 người và quý 3 xin nghỉ khá nhiều (75%) nên phải tăng cường tuyển dụng và luân chuyển từ các chi nhánh khác.

# %% [markdown]
# **STEP 2:** On a blank piece of paper, describe or sketch 3-4 different ways you could show this data, such that the key takeaways would be obvious to the CEO.

# %% [markdown]
# Có thể sử dụng những biểu đồ như là:
# - Cột chồng
# - Cột nhóm
# - Miền
# - Đường
#
# biểu diễn sự thay đổi về số lượng nhân viên với mỗi thuộc tính là 1 nhóm/miền.

# %% [markdown]
# STEP 3: From your initial ideas, select the approach that you feel would be the most effective. Create that chart or charts in the graphing tool of your choice. Be sure to add a meaningful chart title, data labels, and annotations to help support your message.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
